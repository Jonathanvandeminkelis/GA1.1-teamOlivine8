# %%
def add(a,b):
    return a + b

print(add(5,7))
print(add(2,5))
print(add(8,1))

# %%
def sum_list(values):
    total = 0
    for v in values:
        total = add(total, v)
    return total
print(sum_list([1, 2, 3, 4])) 
print(sum_list([]))
# Out:
# 10
# 0
